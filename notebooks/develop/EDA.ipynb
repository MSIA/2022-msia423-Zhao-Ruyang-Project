# %%
import pandas as pd
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split
# Regression
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_absolute_percentage_error
df = pd.read_csv('Clean_Dataset.csv', index_col=0)
df
# Out:
#          airline   flight source_city departure_time stops   arrival_time  \
# 0       SpiceJet  SG-8709       Delhi        Evening  zero          Night
# 1       SpiceJet  SG-8157       Delhi  Early_Morning  zero        Morning
# 2        AirAsia   I5-764       Delhi  Early_Morning  zero  Early_Morning
# 3        Vistara   UK-995       Delhi        Morning  zero      Afternoon
# 4        Vistara   UK-963       Delhi        Morning  zero        Morning
# ...          ...      ...         ...            ...   ...            ...
# 300148   Vistara   UK-822     Chennai        Morning   one        Evening
# 300149   Vistara   UK-826     Chennai      Afternoon   one          Night
# 300150   Vistara   UK-832     Chennai  Early_Morning   one          Night
# 300151   Vistara   UK-828     Chennai  Early_Morning   one        Evening
# 300152   Vistara   UK-822     Chennai        Morning   one        Evening
#
#        destination_city     class  duration  days_left  price
# 0                Mumbai   Economy      2.17          1   5953
# 1                Mumbai   Economy      2.33          1   5953
# 2                Mumbai   Economy      2.17          1   5956
# 3                Mumbai   Economy      2.25          1   5955
# 4                Mumbai   Economy      2.33          1   5955
# ...                 ...       ...       ...        ...    ...
# 300148        Hyderabad  Business     10.08         49  69265
# 300149        Hyderabad  Business     10.42         49  77105
# 300150        Hyderabad  Business     13.83         49  79099
# 300151        Hyderabad  Business     10.00         49  81585
# 300152        Hyderabad  Business     10.08         49  81585
#
# [300153 rows x 11 columns]

# %%
dic = {'zero': 0,
#        'one': 1,
       'two_or_more': 2}
# df.stops.map(dic).isna()
# data['stops']
set(df.stops)
# .issubset(set(dic))
# Out:
# {'one', 'two_or_more', 'zero'}

# %%
df['a']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'a'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /var/folders/9c/54g7vhw56cj8bgt33z50wxdm0000gn/T/ipykernel_75798/707118431.py in <module>
# ----> 1 df['a']
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'a'

# %%
from datetime import datetime
time.strptime('12:01', '%H:%M')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/9c/54g7vhw56cj8bgt33z50wxdm0000gn/T/ipykernel_75798/2923651204.py in <module>
#       1 from datetime import datetime
# ----> 2 time.strptime('12:01', '%H:%M')
#
# AttributeError: type object 'datetime.time' has no attribute 'strptime'

# %%
data = df.drop(['flight', 'arrival_time'], axis=1)
data.stops
# Out:
#          airline source_city departure_time stops destination_city     class  \
# 0       SpiceJet       Delhi        Evening  zero           Mumbai   Economy
# 1       SpiceJet       Delhi  Early_Morning  zero           Mumbai   Economy
# 2        AirAsia       Delhi  Early_Morning  zero           Mumbai   Economy
# 3        Vistara       Delhi        Morning  zero           Mumbai   Economy
# 4        Vistara       Delhi        Morning  zero           Mumbai   Economy
# ...          ...         ...            ...   ...              ...       ...
# 300148   Vistara     Chennai        Morning   one        Hyderabad  Business
# 300149   Vistara     Chennai      Afternoon   one        Hyderabad  Business
# 300150   Vistara     Chennai  Early_Morning   one        Hyderabad  Business
# 300151   Vistara     Chennai  Early_Morning   one        Hyderabad  Business
# 300152   Vistara     Chennai        Morning   one        Hyderabad  Business
#
#         duration  days_left  price
# 0           2.17          1   5953
# 1           2.33          1   5953
# 2           2.17          1   5956
# 3           2.25          1   5955
# 4           2.33          1   5955
# ...          ...        ...    ...
# 300148     10.08         49  69265
# 300149     10.42         49  77105
# 300150     13.83         49  79099
# 300151     10.00         49  81585
# 300152     10.08         49  81585
#
# [300153 rows x 9 columns]

# %%
def convert_stops(df, col_name, map):
    data = df.copy()
    data[col_name] = data[col_name].map(map)
    return data

# %%
a = [1,2,3]
def bb(l):
    l[1] = 'a'
bb(a)
a
# Out:
# [1, 'a', 3]

# %%
convert_stops(df, 'stops', dic)
df
# Out:
#          airline   flight source_city departure_time stops   arrival_time  \
# 0       SpiceJet  SG-8709       Delhi        Evening  zero          Night
# 1       SpiceJet  SG-8157       Delhi  Early_Morning  zero        Morning
# 2        AirAsia   I5-764       Delhi  Early_Morning  zero  Early_Morning
# 3        Vistara   UK-995       Delhi        Morning  zero      Afternoon
# 4        Vistara   UK-963       Delhi        Morning  zero        Morning
# ...          ...      ...         ...            ...   ...            ...
# 300148   Vistara   UK-822     Chennai        Morning   one        Evening
# 300149   Vistara   UK-826     Chennai      Afternoon   one          Night
# 300150   Vistara   UK-832     Chennai  Early_Morning   one          Night
# 300151   Vistara   UK-828     Chennai  Early_Morning   one        Evening
# 300152   Vistara   UK-822     Chennai        Morning   one        Evening
#
#        destination_city     class  duration  days_left  price
# 0                Mumbai   Economy      2.17          1   5953
# 1                Mumbai   Economy      2.33          1   5953
# 2                Mumbai   Economy      2.17          1   5956
# 3                Mumbai   Economy      2.25          1   5955
# 4                Mumbai   Economy      2.33          1   5955
# ...                 ...       ...       ...        ...    ...
# 300148        Hyderabad  Business     10.08         49  69265
# 300149        Hyderabad  Business     10.42         49  77105
# 300150        Hyderabad  Business     13.83         49  79099
# 300151        Hyderabad  Business     10.00         49  81585
# 300152        Hyderabad  Business     10.08         49  81585
#
# [300153 rows x 11 columns]

# %%
dic = {'zero': 0,
       'one': 1,
       'two_or_more': 2}
data.stops = data.stops.map(dic)
data['stops']
# Out:
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
#           ..
# 300148   NaN
# 300149   NaN
# 300150   NaN
# 300151   NaN
# 300152   NaN
# Name: stops, Length: 300153, dtype: float64

# %%
data = pd.get_dummies(data)

# %%
#Train test split
X = data.drop('price', axis=1)
y = data['price']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=123)
rm = RandomForestRegressor(n_estimators=200, random_state=123, n_jobs=-1, oob_score=True)
rm.fit(X_train, y_train)

#Output the evaluation metrics of the predictions on the validation set
print("MSE", mean_squared_error(y_test, rm.predict(X_test)))
print("MAE", mean_absolute_error(y_test, rm.predict(X_test)))
print("MAPE", mean_absolute_percentage_error(y_test, rm.predict(X_test)))
# Out:
# /Users/zry/opt/anaconda3/lib/python3.8/site-packages/sklearn/base.py:445: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# MSE 8074523.60498861
# MAE 1109.2006236731042
# MAPE 0.07089740797339492
